# %%
import json
import time
from datetime import datetime, timedelta
import random
from faker import Faker
import logging
import uuid
import pandas as pd
from pathlib import Path

# Set up logging
logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger(__name__)

# Initialize Faker
fake = Faker()

# Configuration
TOTAL_RECORDS = 10009900000  # Total number of records to generate
BATCH_SIZE = 10000  # Records to process at once to manage memory
OUTPUT_DIR = "data"
CSV_FILENAME = "employee_records.csv"

# Rich data schema configuration
DEPARTMENTS = {
    "Engineering": {
        "salary_range": (70000, 160000),
        "positions": [
            "Software Engineer",
            "DevOps Engineer",
            "QA Engineer",
            "Engineering Manager",
        ],
    },
    "Sales": {
        "salary_range": (50000, 130000),
        "positions": [
            "Sales Representative",
            "Account Executive",
            "Sales Manager",
            "Sales Director",
        ],
    },
    "Marketing": {
        "salary_range": (45000, 120000),
        "positions": [
            "Marketing Specialist",
            "Content Manager",
            "Marketing Director",
            "Brand Manager",
        ],
    },
    "HR": {
        "salary_range": (40000, 110000),
        "positions": ["HR Coordinator", "HR Manager", "Recruiter", "HR Director"],
    },
    "Finance": {
        "salary_range": (55000, 140000),
        "positions": [
            "Financial Analyst",
            "Accountant",
            "Finance Manager",
            "Controller",
        ],
    },
}

OFFICE_LOCATIONS = {
    "New York": {"timezone": "America/New_York", "country": "USA"},
    "San Francisco": {"timezone": "America/Los_Angeles", "country": "USA"},
    "London": {"timezone": "Europe/London", "country": "UK"},
    "Singapore": {"timezone": "Asia/Singapore", "country": "Singapore"},
    "Sydney": {"timezone": "Australia/Sydney", "country": "Australia"},
}

EMPLOYMENT_STATUS = ["Full-time", "Part-time", "Contract", "Remote"]
PERFORMANCE_RATINGS = [
    "Exceptional",
    "Exceeds Expectations",
    "Meets Expectations",
    "Needs Improvement",
]


def generate_record():
    """Generate a single employee record with detailed information"""
    join_date = datetime.now() - timedelta(days=random.randint(0, 3650))
    department = random.choice(list(DEPARTMENTS.keys()))
    position = random.choice(DEPARTMENTS[department]["positions"])
    office_location = random.choice(list(OFFICE_LOCATIONS.keys()))

    return {
        "record_id": str(uuid.uuid4()),
        "timestamp": str(int(time.time() * 1000)),
        "version": "2.0",
        "data_center": random.choice(["dc-east", "dc-west", "dc-eu"]),
        "employee_id": f"EMP-{str(uuid.uuid4())[:8].upper()}",
        "name": fake.name(),
        "email": fake.email(),
        "phone": fake.phone_number(),
        "department": department,
        "position": position,
        "experience_level": random.choice(["Junior", "Mid-level", "Senior", "Expert"]),
        "employment_status": random.choice(EMPLOYMENT_STATUS),
        "salary": random.randint(*DEPARTMENTS[department]["salary_range"]),
        "bonus_eligible": random.choice([True, False]),
        "stock_options": random.randint(0, 10000) if random.random() > 0.5 else 0,
        "office": office_location,
        "timezone": OFFICE_LOCATIONS[office_location]["timezone"],
        "country": OFFICE_LOCATIONS[office_location]["country"],
        "remote_work_eligible": random.choice([True, False]),
        "join_date": join_date.strftime("%Y-%m-%d"),
        "last_promotion_date": (
            join_date + timedelta(days=random.randint(180, 1000))
        ).strftime("%Y-%m-%d"),
        "last_review_date": (
            datetime.now() - timedelta(days=random.randint(0, 365))
        ).strftime("%Y-%m-%d"),
        "last_rating": random.choice(PERFORMANCE_RATINGS),
        "rating_date": (
            datetime.now() - timedelta(days=random.randint(0, 180))
        ).strftime("%Y-%m-%d"),
        "projects_completed": random.randint(1, 20),
    }


def main():
    # Create output directory if it doesn't exist
    Path(OUTPUT_DIR).mkdir(parents=True, exist_ok=True)
    output_path = Path(OUTPUT_DIR) / CSV_FILENAME

    # Generate and save data in batches
    total_batches = TOTAL_RECORDS // BATCH_SIZE

    logger.info(
        f"Starting data generation: {TOTAL_RECORDS} records in {total_batches} batches"
    )

    # Generate first batch and create CSV with headers
    first_batch = [generate_record() for _ in range(BATCH_SIZE)]
    df = pd.DataFrame(first_batch)
    # df.to_csv(output_path, index=False)
    df.to_csv(output_path, mode="a", header=False, index=False)

    logger.info(f"Created CSV file and wrote first batch of {BATCH_SIZE} records")

    # Generate and append remaining batches
    for batch_num in range(1, total_batches):
        records = [generate_record() for _ in range(BATCH_SIZE)]
        df = pd.DataFrame(records)
        df.to_csv(output_path, mode="a", header=False, index=False)
        logger.info(f"Completed batch {batch_num + 1}/{total_batches}")

    logger.info(f"Data generation complete. File saved to: {output_path}")
    logger.info(f"Total records generated: {TOTAL_RECORDS}")


if __name__ == "__main__":
    main()
# Out:
# 2024-11-08 12:24:10,566 - INFO - Starting data generation: 10009900000 records in 1000990 batches
# 2024-11-08 12:24:14,323 - INFO - Created CSV file and wrote first batch of 10000 records
# 2024-11-08 12:24:19,291 - INFO - Completed batch 2/1000990
# 2024-11-08 12:24:25,085 - INFO - Completed batch 3/1000990
# 2024-11-08 12:24:30,032 - INFO - Completed batch 4/1000990
# 2024-11-08 12:24:34,552 - INFO - Completed batch 5/1000990
# 2024-11-08 12:24:39,871 - INFO - Completed batch 6/1000990
# 2024-11-08 12:24:45,162 - INFO - Completed batch 7/1000990
# 2024-11-08 12:24:51,355 - INFO - Completed batch 8/1000990
# 2024-11-08 12:24:56,352 - INFO - Completed batch 9/1000990
# 2024-11-08 12:25:01,253 - INFO - Completed batch 10/1000990
# 2024-11-08 12:25:05,953 - INFO - Completed batch 11/1000990
# 2024-11-08 12:25:10,939 - INFO - Completed batch 12/1000990
# 2024-11-08 12:25:16,010 - INFO - Completed batch 13/1000990
# 2024-11-08 12:25:20,744 - INFO - Completed batch 14/1000990
# 2024-11-08 12:25:25,652 - INFO - Completed batch 15/1000990
# 2024-11-08 12:25:30,700 - INFO - Completed batch 16/1000990
# 2024-11-08 12:25:35,520 - INFO - Completed batch 17/1000990
# 2024-11-08 12:25:40,234 - INFO - Completed batch 18/1000990
# 2024-11-08 12:25:48,792 - INFO - Completed batch 19/1000990
# 2024-11-08 12:25:55,468 - INFO - Completed batch 20/1000990
# 2024-11-08 12:26:02,936 - INFO - Completed batch 21/1000990
# 2024-11-08 12:26:08,195 - INFO - Completed batch 22/1000990
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 161
#     157     logger.info(f"Total records generated: {TOTAL_RECORDS}")
#     160 if __name__ == "__main__":
# --> 161     main()
#
# Cell In[6], line 151, in main()
#     149 # Generate and append remaining batches
#     150 for batch_num in range(1, total_batches):
# --> 151     records = [generate_record() for _ in range(BATCH_SIZE)]
#     152     df = pd.DataFrame(records)
#     153     df.to_csv(output_path, mode="a", header=False, index=False)
#
# Cell In[6], line 151, in <listcomp>(.0)
#     149 # Generate and append remaining batches
#     150 for batch_num in range(1, total_batches):
# --> 151     records = [generate_record() for _ in range(BATCH_SIZE)]
#     152     df = pd.DataFrame(records)
#     153     df.to_csv(output_path, mode="a", header=False, index=False)
#
# Cell In[6], line 101, in generate_record()
#      91 position = random.choice(DEPARTMENTS[department]["positions"])
#      92 office_location = random.choice(list(OFFICE_LOCATIONS.keys()))
#      94 return {
#      95     "record_id": str(uuid.uuid4()),
#      96     "timestamp": str(int(time.time() * 1000)),
#      97     "version": "2.0",
#      98     "data_center": random.choice(["dc-east", "dc-west", "dc-eu"]),
#      99     "employee_id": f"EMP-{str(uuid.uuid4())[:8].upper()}",
#     100     "name": fake.name(),
# --> 101     "email": fake.email(),
#     102     "phone": fake.phone_number(),
#     103     "department": department,
#     104     "position": position,
#     105     "experience_level": random.choice(["Junior", "Mid-level", "Senior", "Expert"]),
#     106     "employment_status": random.choice(EMPLOYMENT_STATUS),
#     107     "salary": random.randint(*DEPARTMENTS[department]["salary_range"]),
#     108     "bonus_eligible": random.choice([True, False]),
#     109     "stock_options": random.randint(0, 10000) if random.random() > 0.5 else 0,
#     110     "office": office_location,
#     111     "timezone": OFFICE_LOCATIONS[office_location]["timezone"],
#     112     "country": OFFICE_LOCATIONS[office_location]["country"],
#     113     "remote_work_eligible": random.choice([True, False]),
#     114     "join_date": join_date.strftime("%Y-%m-%d"),
#     115     "last_promotion_date": (
#     116         join_date + timedelta(days=random.randint(180, 1000))
#     117     ).strftime("%Y-%m-%d"),
#     118     "last_review_date": (
#     119         datetime.now() - timedelta(days=random.randint(0, 365))
#     120     ).strftime("%Y-%m-%d"),
#     121     "last_rating": random.choice(PERFORMANCE_RATINGS),
#     122     "rating_date": (
#     123         datetime.now() - timedelta(days=random.randint(0, 180))
#     124     ).strftime("%Y-%m-%d"),
#     125     "projects_completed": random.randint(1, 20),
#     126 }
#
# File ~/.local/lib/python3.11/site-packages/faker/utils/decorators.py:36, in lowercase.<locals>.wrapper(*args, **kwargs)
#      34 @wraps(fn)
#      35 def wrapper(*args: Tuple[T, ...], **kwargs: Dict[str, T]) -> str:
# ---> 36     return fn(*args, **kwargs).lower()
#
# File ~/.local/lib/python3.11/site-packages/faker/providers/internet/__init__.py:233, in Provider.email(self, safe, domain)
#     231     email = f"{self.user_name()}@{domain}"
#     232 elif safe:
# --> 233     email = f"{self.user_name()}@{self.safe_domain_name()}"
#     234 else:
#     235     pattern: str = self.random_element(self.email_formats)
#
# File ~/.local/lib/python3.11/site-packages/faker/utils/decorators.py:28, in slugify_unicode.<locals>.wrapper(*args, **kwargs)
#      26 @wraps(fn)
#      27 def wrapper(*args: Tuple[T, ...], **kwargs: Dict[str, T]) -> str:
# ---> 28     return text.slugify(fn(*args, **kwargs), allow_unicode=True)
#
# File ~/.local/lib/python3.11/site-packages/faker/providers/internet/__init__.py:285, in Provider.user_name(self)
#     282 @slugify_unicode
#     283 def user_name(self) -> str:
#     284     pattern: str = self.random_element(self.user_name_formats)
# --> 285     return self._to_ascii(self.bothify(self.generator.parse(pattern)).lower())
#
# File ~/.local/lib/python3.11/site-packages/faker/generator.py:175, in Generator.parse(self, text)
#     161 def parse(self, text: str) -> str:
#     162     """
#     163     Replaces tokens like '{{ tokenName }}' or '{{tokenName}}' in a string with
#     164     the result from the token method call. Arguments can be parsed by using an
#    (...)
#     173     generator.parse('{{ color:red_rgb }} - {{ pyint:small }}')
#     174     """
# --> 175     return _re_token.sub(self.__format_token, text)
#
# File ~/.local/lib/python3.11/site-packages/faker/generator.py:189, in Generator.__format_token(self, matches)
#     187     formatted = str(self.format(formatter, **arguments))
#     188 else:
# --> 189     formatted = str(self.format(formatter))
#     191 return "".join(formatted)
#
# File ~/.local/lib/python3.11/site-packages/faker/generator.py:88, in Generator.format(self, formatter, *args, **kwargs)
#      84 def format(self, formatter: str, *args: Any, **kwargs: Any) -> str:
#      85     """
#      86     This is a secure way to make a fake from another Provider.
#      87     """
# ---> 88     return self.get_formatter(formatter)(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/faker/providers/person/__init__.py:212, in Provider.last_name(self)
#     211 def last_name(self) -> str:
# --> 212     return self.random_element(self.last_names)
#
# File ~/.local/lib/python3.11/site-packages/faker/providers/__init__.py:553, in BaseProvider.random_element(self, elements)
#     536 def random_element(self, elements: ElementsType[T] = ("a", "b", "c")) -> T:
#     537     """Generate a randomly sampled object from ``elements``.
#     538
#     539     For information on the ``elements`` argument, please refer to
#    (...)
#     550              ])
#     551     """
# --> 553     return self.random_elements(elements, length=1)[0]
#
# File ~/.local/lib/python3.11/site-packages/faker/providers/__init__.py:501, in BaseProvider.random_elements(self, elements, length, unique, use_weighting)
#     498     choices = elements
#     499     probabilities = None
# --> 501 return fn(
#     502     tuple(choices),
#     503     probabilities,
#     504     self.generator.random,
#     505     length=length,
#     506 )
#
# File ~/.local/lib/python3.11/site-packages/faker/utils/distribution.py:73, in choices_distribution(a, p, random, length)
#      71         return [random.choice(a)]
#      72     else:
# ---> 73         return random.choices(a, weights=p, k=length)
#      74 else:
#      75     choices = []
#
# File /usr/lib/python3.11/random.py:492, in Random.choices(self, population, weights, cum_weights, k)
#     490     return [population[floor(random() * n)] for i in _repeat(None, k)]
#     491 try:
# --> 492     cum_weights = list(_accumulate(weights))
#     493 except TypeError:
#     494     if not isinstance(weights, int):
#
# KeyboardInterrupt:
